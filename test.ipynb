# %%
liste = ['ABJC.ci.csv', 'BICC.ci.csv',
       'BNBC.ci.csv', 'BOABF.bf.csv', 'BOAC.ci.csv', 'BOAM.ml.csv',
       'BOAN.ne.csv', 'BOAS.sn.csv', 'CABC.ci.csv', 'CBIBF.bf.csv',
       'CFAC.ci.csv', 'CIEC.ci.csv', 'ECOC.ci.csv', 'ETIT.tg.csv',
       'NEIC.ci.csv', 'NSBC.ci.csv', 'NTLC.ci.csv', 'ONTBF.bf.csv',
       'PALC.ci.csv', 'PRSC.ci.csv', 'SAFC.ci.csv', 'SCRC.ci.csv',
       'SDCC.ci.csv', 'SGBC.ci.csv', 'SHEC.ci.csv', 'SICC.ci.csv',
       'SIVC.ci.csv', 'SLBC.ci.csv', 'SOGC.ci.csv', 'STAC.ci.csv',
       'STBC.ci.csv', 'UNLC.ci.csv', 'UNXC.ci.csv']

# %%
import os

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 os.getcd()
#
# AttributeError: module 'os' has no attribute 'getcd'

# %%
import pandas as pd
df = pd.read_csv("streamlit_app/Action.csv")

# %%
df
# Out:
#      Unnamed: 0.1  Unnamed: 0  ABJC.ci.csv  BICB.bj.csv  BICC.ci.csv  \
# 0               0           0         1780       5495.0      15900.0
# 1               1           1         1750       5295.0      15400.0
# 2               2           2         2020       5600.0      10000.0
# 3               3           3         1700       5350.0      16580.0
# 4               4           4         2230       5285.0       9740.0
# ..            ...         ...          ...          ...          ...
# 242           242         242         2300          NaN       9740.0
# 243           243         243         2240          NaN      10805.0
# 244           244         244         1795          NaN          NaN
# 245           245         245         2250          NaN          NaN
# 246           246         246         2200          NaN          NaN
#
#      BNBC.ci.csv BOABF.bf.csv BOAC.ci.csv         BOAM.ml.csv BOAN.ne.csv  \
# ...
